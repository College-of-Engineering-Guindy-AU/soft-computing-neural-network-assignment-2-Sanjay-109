# %%
import numpy as np 
import pandas as pd
import os

# Define the path to the directory containing your code
code_dir = r"D:\Codes\soft_computing_assignment_2"

# Construct the path to the "input" directory within the code directory
input_dir = os.path.join(code_dir, "input")

# Iterate over the files in the "input" directory
for dirname, _, filenames in os.walk(input_dir):
    for filename in filenames:
        # Construct the full path of each file
        file_path = os.path.join(dirname, filename)
        # Print the full path of each file
        print(file_path)
# Out:
# D:\Codes\soft_computing_assignment_2\input\stopwords.txt
# D:\Codes\soft_computing_assignment_2\input\test.tsv
# D:\Codes\soft_computing_assignment_2\input\train.tsv

# %%
train_fname = r"D:\Codes\soft_computing_assignment_2\input\train.tsv"
test_fname = r"D:\Codes\soft_computing_assignment_2\input\test.tsv"

# %%
df_train = pd.read_csv(train_fname, sep='\t')
df_test = pd.read_csv(test_fname, sep='\t')

# %%
df_train.head()
# Out:
#    sentiment                                             review
# 0          1  But it's really slow to catch on . For me a mo...
# 1          1  To me, it's controversial how this movie has s...
# 2          1  The movie is a tricky and the story is good, b...
# 3          0  I can not believe that this movie received all...
# 4          2  Usually the debate is wether godfather or Good...

# %%
df_train['sentiment'].value_counts()
# Out:
# sentiment
# 2    10932
# 0    10929
# 1    10884
# Name: count, dtype: int64

# %%
ax = df_train['sentiment'].value_counts().sort_index().plot(kind='bar', title='Counts of sentiments', figsize=(10, 5))
ax.set_xlabel('Sentiment')
# Out:
# Text(0.5, 0, 'Sentiment')

# %%
import re
import nltk
import spacy

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('wordnet')

if not spacy.util.is_package("en_core_web_sm"):
    spacy.cli.download("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/

# %%
to_replace = {
    "don\'t": "do not",
    "dont": "do not",
    "doesn\'t": "does not",
    "doesnt": "does not",
    "didn\'t": "did not",
    "didnt": "did not",
    "shouldn\'t": "should not",
    "shouldnt": "should not",
    "mustn\'t": "must not",
    "mustnt": "must not",
    "haven\'t": "have not",
    "hvn\'t": "have not",
    "havent": "have not",
    "hadn\'t": "had not",
    "hadnt": "had not",
    "can\'t": "can not",
    "cant": "can not",
    "cannot": "can not",
    "cann\'t": "can not",
    "couldn\'t": "could not",
    "couldnt": "could not",
    "aren\'t": "are not",
    "arent": "are not",
    "isn\'t": "is not",
    "isnt": "is not",
    "wasn\'t": "was not",
    "wasnt": "was not",
    "weren\'t": "were not",
    "werent": "were not",
    "won\'t": "will not",
    "wont": "will not",
    "wouldn\'t": "would not",
    "wouldnt": "would not",
}

# %%
stopwords = []

with open(r'D:\Codes\soft_computing_assignment_2\input\stopwords.txt', 'r') as file:
    for line in file:
        stopwords.append(line.strip())

print(stopwords)
# Out:
# ['i', 'me', 'my', 'mine', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'how', 'when', 'where', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'among', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 'can', 'will', 'just', 'should', 'now', 'must', 'thus']

# %%
def replace_contractions(sentence, to_replace):
    pattern = re.compile(r'\b(' + '|'.join(to_replace.keys()) + r')\b')
    
    return pattern.sub(lambda x: to_replace[x.group()], sentence)

def decontracted(phrase):
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
lemmatizer = WordNetLemmatizer()
nlp = spacy.load("en_core_web_sm")

def clean_text(text):
    text = text.lower()
    text = replace_contractions(text, to_replace)
    text = decontracted(text)
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    words = word_tokenize(text)

    filtered_words = [word for word in words if not word in stopwords  and len(word) > 1]
    lemmas = []
    for word in filtered_words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    sentence = ' '.join(lemmas)
    doc = nlp(sentence)
    lemmas = [token.lemma_ for token in doc]

    return ' '.join(lemmas)

# %%
example = "I don't like this movie, it doesn't make sense. he won't watch it again in 2024 @ !"
print(clean_text(example))
# Out:
# not like movie not make sense not watch

# %%
from tqdm import tqdm
tqdm.pandas()

df_train['words'] = df_train['review'].progress_apply(clean_text)
df_test['words'] = df_test['review'].progress_apply(clean_text)
# Out:
# 100%|██████████| 32745/32745 [08:05<00:00, 67.50it/s]
# 100%|██████████| 2681/2681 [00:30<00:00, 88.68it/s]

# %%
df_negative = df_train[df_train['sentiment'] == 0]
df_neutral = df_train[df_train['sentiment'] == 1]
df_positive = df_train[df_train['sentiment'] == 2]

def count_words(df):
    word_counts = {}
    for review in df['words']:
        words = review.split()
        for word in words:
            if word in word_counts:
                word_counts[word] += 1
            else:
                word_counts[word] = 1
    return word_counts

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def create_wordcloud(word_counts, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# %%
word_counts_negative = count_words(df_negative)
create_wordcloud(word_counts_negative, 'Most Frequent Words in Negative Reviews')

word_counts_neutral = count_words(df_neutral)
create_wordcloud(word_counts_neutral, 'Most Frequent Words in Neutral Reviews')

word_counts_positive = count_words(df_positive)
create_wordcloud(word_counts_positive, 'Most Frequent Words in Positive Reviews')

# %%
from collections import Counter

def get_corpus(df):
    corpus = []
    for i in tqdm(range(len(df))):
        corpus.append(df['words'].values[i].split())
    corpus = Counter(np.hstack(corpus))
    corpus2 = sorted(corpus, key=corpus.get, reverse=True)
    corpus2 = ['<PAD>', '<UNK>'] + corpus2
    vocab = {word: idx for idx, word in enumerate(corpus2, 1)}
    return corpus, vocab

# %%
combined_df = pd.concat([df_train, df_test], ignore_index=True)
corpus, vocab = get_corpus(combined_df)
# Out:
# 100%|██████████| 35426/35426 [00:00<00:00, 82219.14it/s]

# %%
import pickle

with open(r"D:\Codes\soft_computing_assignment_2\tokenizer.pkl", 'wb') as file:
    pickle.dump(vocab, file)

# %%
def phrase_to_ints(text):
    words = [word for word in text.split()]
    ints = [vocab.get(word, vocab['<UNK>']) for word in words]
    return ints

# %%
df_train['ints'] = df_train['words'].progress_apply(phrase_to_ints)
df_test['ints'] = df_test['words'].progress_apply(phrase_to_ints)
# Out:
# 100%|██████████| 32745/32745 [00:01<00:00, 29795.82it/s]
# 100%|██████████| 2681/2681 [00:00<00:00, 45573.08it/s]

# %%
def pad_sequences(phrase_to_int, seq_length):
    if not isinstance(phrase_to_int[0], list):
        phrase_to_int = [phrase_to_int]
    pad_sequences = np.zeros((len(phrase_to_int), seq_length), dtype=int)
    for idx,row in tqdm(enumerate(phrase_to_int), total=len(phrase_to_int)):
        pad_sequences[idx, :len(row)] = np.array(row)[:seq_length]
    return pad_sequences

# %%
seq_length = 300

train_padded_seqs = pad_sequences(df_train['ints'], seq_length)
train_labels = df_train['sentiment'].tolist()
test_padded_seqs = pad_sequences(df_test['ints'], seq_length)
test_labels = df_test['sentiment'].tolist()
# Out:
# 100%|██████████| 32745/32745 [00:00<00:00, 138137.60it/s]
# 100%|██████████| 2681/2681 [00:00<00:00, 240625.89it/s]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(train_padded_seqs, train_labels, test_size=0.2, random_state=42)

# %%
import torch

X_train_tensor = torch.tensor(X_train)
Y_train_tensor = torch.tensor(Y_train)
X_val_tensor = torch.tensor(X_val)
Y_val_tensor = torch.tensor(Y_val)
X_test_tensor = torch.tensor(test_padded_seqs)
Y_test_tensor = torch.tensor(test_labels)

# %%
from torch.utils.data import DataLoader, TensorDataset

batch_size = 32

train_data = TensorDataset(X_train_tensor, Y_train_tensor)
valid_data = TensorDataset(X_val_tensor, Y_val_tensor)
test_data = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, drop_last=True)
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
dataiter = iter(train_loader)
sample_x, sample_y = dataiter.__next__()

print('Sample input size: ', sample_x.size())
print('Sample label size: ', sample_y.size())
print('Sample input: \n', sample_x)

print('\nData loader size: {} (train), {} (val), {} (test)'.format(len(train_loader), len(valid_loader), len(test_loader)))
print('Train: ', X_train.shape)
print('Val: ', X_val.shape)
print('Test: ', test_padded_seqs.shape)
# Out:
# Sample input size:  torch.Size([32, 300])
# Sample label size:  torch.Size([32])
# Sample input:
#  tensor([[   31,  1717,  1064,  ...,     0,     0,     0],
#         [  144,   215,   290,  ...,     0,     0,     0],
#         [10583, 10450,  1763,  ...,     0,     0,     0],
#         ...,
#         [ 6024,  4792,     9,  ...,   305, 13943, 18543],
#         [  177,   676,     4,  ...,     0,     0,     0],
#         [  145,   124,    11,  ...,     0,     0,     0]], dtype=torch.int32)
#
# Data loader size: 818 (train), 204 (val), 83 (test)
# Train:  (26196, 300)
# Val:  (6549, 300)
# Test:  (2681, 300)

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda:0

# %%
import torch.nn as nn

class SentimentRNN(nn.Module):
    def __init__(self, vocab_size, output_size, embedding_dim, hidden_dim, n_layers, drop_prob=0.5):
        super(SentimentRNN, self).__init__()

        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)

        self.fc = nn.Linear(hidden_dim, output_size)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x, hidden):
        batch_size = x.size(0)

        embeds = self.embedding(x)
        lstm_out, hidden = self.lstm(embeds, hidden)
        
        lstm_last_out = lstm_out[:, -1, :]

        out = self.dropout(lstm_last_out)
        out = self.fc(out)
        out = self.softmax(out)

        return out, hidden

    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device),
                  weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device))

        return hidden

# %%
n_vocab = len(vocab) + 1
n_embed = 128
n_hidden = 256
n_output = 3
n_layers = 2
learning_rate = 0.001

# %%
net = SentimentRNN(n_vocab, n_output, n_embed, n_hidden, n_layers)
print(net)
# Out:
# SentimentRNN(
#   (embedding): Embedding(55991, 128)
#   (lstm): LSTM(128, 256, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=256, out_features=3, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
from sklearn.metrics import accuracy_score

n_epochs = 20
eval_every = 100
clip = 5

min_val_loss = float('inf')
model_name = r"D:\Codes\soft_computing_assignment_2\trained_model.pth"

train_losses = []
valid_losses = []

# %%
net.to(device)

for e in range(n_epochs):
    counter = 0
    epoch_train_losses = []

    h = net.init_hidden(batch_size)

    net.train()
    
    for inputs, labels in train_loader:
        counter += 1

        inputs, labels = inputs.to(device), labels.to(device)
        h = tuple([each.data for each in h])

        optimizer.zero_grad()

        output, h = net(inputs, h)

        loss = criterion(output, labels)
        loss.backward()
        nn.utils.clip_grad_norm_(net.parameters(), clip)
        optimizer.step()

        train_loss = loss.item()
        epoch_train_losses.append(train_loss)

        if counter % eval_every == 0:
            val_h = net.init_hidden(batch_size)
            val_losses = []
            val_predictions = []
            val_targets = []

            net.eval()
            with torch.no_grad():
                for inputs, labels in valid_loader:
                    val_h = tuple([each.data for each in val_h])
                    inputs, labels = inputs.to(device), labels.to(device)

                    output, val_h = net(inputs, val_h)
                    val_loss = criterion(output, labels)

                    val_losses.append(val_loss.item())

                    _, prediction = torch.max(output, 1)
                    val_predictions.extend(prediction.cpu().numpy())
                    val_targets.extend(labels.cpu().numpy())

            mean_val_loss = np.mean(val_losses)
            val_accuracy = accuracy_score(val_targets, val_predictions)

            print("Epoch: {}/{},".format(e + 1, n_epochs),
                  "Step: {},".format(counter),
                  "Loss: {:.6f},".format(loss.item()),
                  "Val loss: {:.6f},".format(mean_val_loss),
                  "Val accuracy: {:.6f}".format(val_accuracy))

            if mean_val_loss < min_val_loss:
                print("Validation loss decreased ({:.6f} --> {:.6f}). Saving model...".format(min_val_loss, mean_val_loss))
                min_val_loss = mean_val_loss
                torch.save(net.state_dict(), model_name)

            net.train()

    valid_losses.append(mean_val_loss)
    epoch_train_loss = np.mean(epoch_train_losses)
    train_losses.append(epoch_train_loss)
# Out:
# Epoch: 1/20, Step: 100, Loss: 1.097884, Val loss: 1.098934, Val accuracy: 0.341759
# Validation loss decreased (inf --> 1.098934). Saving model...
# Epoch: 1/20, Step: 200, Loss: 1.131407, Val loss: 1.102376, Val accuracy: 0.342065
# Epoch: 1/20, Step: 300, Loss: 1.132409, Val loss: 1.099049, Val accuracy: 0.330882
# Epoch: 1/20, Step: 400, Loss: 1.093296, Val loss: 1.097872, Val accuracy: 0.338695
# Validation loss decreased (1.098934 --> 1.097872). Saving model...
# Epoch: 1/20, Step: 500, Loss: 1.090220, Val loss: 1.097460, Val accuracy: 0.342984
# Validation loss decreased (1.097872 --> 1.097460). Saving model...
# Epoch: 1/20, Step: 600, Loss: 1.099935, Val loss: 1.097635, Val accuracy: 0.343137
# Epoch: 1/20, Step: 700, Loss: 1.104342, Val loss: 1.098477, Val accuracy: 0.342525
# Epoch: 1/20, Step: 800, Loss: 1.112324, Val loss: 1.097992, Val accuracy: 0.327819
# Epoch: 2/20, Step: 100, Loss: 1.095278, Val loss: 1.098808, Val accuracy: 0.342984
# Epoch: 2/20, Step: 200, Loss: 1.102914, Val loss: 1.098138, Val accuracy: 0.331648
# Epoch: 2/20, Step: 300, Loss: 1.061396, Val loss: 1.098553, Val accuracy: 0.335784
# Epoch: 2/20, Step: 400, Loss: 1.090319, Val loss: 1.097245, Val accuracy: 0.346201
# Validation loss decreased (1.097460 --> 1.097245). Saving model...
# Epoch: 2/20, Step: 500, Loss: 1.106242, Val loss: 1.097630, Val accuracy: 0.344056
# Epoch: 2/20, Step: 600, Loss: 1.119433, Val loss: 1.099125, Val accuracy: 0.342678
# Epoch: 2/20, Step: 700, Loss: 1.099818, Val loss: 1.097533, Val accuracy: 0.342984
# Epoch: 2/20, Step: 800, Loss: 1.108799, Val loss: 1.097577, Val accuracy: 0.342984
# Epoch: 3/20, Step: 100, Loss: 1.084201, Val loss: 1.097573, Val accuracy: 0.344056
# Epoch: 3/20, Step: 200, Loss: 1.094146, Val loss: 1.098325, Val accuracy: 0.342984
# Epoch: 3/20, Step: 300, Loss: 1.104699, Val loss: 1.097602, Val accuracy: 0.342218
# Epoch: 3/20, Step: 400, Loss: 1.113447, Val loss: 1.097536, Val accuracy: 0.342065
# Epoch: 3/20, Step: 500, Loss: 1.096966, Val loss: 1.097634, Val accuracy: 0.331648
# Epoch: 3/20, Step: 600, Loss: 1.101196, Val loss: 1.098152, Val accuracy: 0.342065
# Epoch: 3/20, Step: 700, Loss: 1.098317, Val loss: 1.097703, Val accuracy: 0.341759
# Epoch: 3/20, Step: 800, Loss: 1.104644, Val loss: 1.097758, Val accuracy: 0.342984
# Epoch: 4/20, Step: 100, Loss: 1.100128, Val loss: 1.097877, Val accuracy: 0.344975
# Epoch: 4/20, Step: 200, Loss: 1.093708, Val loss: 1.097405, Val accuracy: 0.350950
# Epoch: 4/20, Step: 300, Loss: 1.076637, Val loss: 1.097248, Val accuracy: 0.350950
# Epoch: 4/20, Step: 400, Loss: 1.106059, Val loss: 1.097548, Val accuracy: 0.342678
# Epoch: 4/20, Step: 500, Loss: 1.111770, Val loss: 1.098245, Val accuracy: 0.343137
# Epoch: 4/20, Step: 600, Loss: 1.086122, Val loss: 1.097970, Val accuracy: 0.342371
# Epoch: 4/20, Step: 700, Loss: 1.099036, Val loss: 1.097513, Val accuracy: 0.343137
# Epoch: 4/20, Step: 800, Loss: 1.092170, Val loss: 1.098501, Val accuracy: 0.330882
# Epoch: 5/20, Step: 100, Loss: 1.099448, Val loss: 1.097830, Val accuracy: 0.340074
# Epoch: 5/20, Step: 200, Loss: 1.086754, Val loss: 1.099098, Val accuracy: 0.339154
# Epoch: 5/20, Step: 300, Loss: 1.080665, Val loss: 1.098357, Val accuracy: 0.329963
# Epoch: 5/20, Step: 400, Loss: 1.072749, Val loss: 1.098831, Val accuracy: 0.344056
# Epoch: 5/20, Step: 500, Loss: 1.072978, Val loss: 1.099742, Val accuracy: 0.346201
# Epoch: 5/20, Step: 600, Loss: 1.099931, Val loss: 1.099339, Val accuracy: 0.342678
# Epoch: 5/20, Step: 700, Loss: 1.070782, Val loss: 1.097956, Val accuracy: 0.342065
# Epoch: 5/20, Step: 800, Loss: 1.098339, Val loss: 1.098098, Val accuracy: 0.342678
# Epoch: 6/20, Step: 100, Loss: 1.080783, Val loss: 1.099184, Val accuracy: 0.342218
# Epoch: 6/20, Step: 200, Loss: 1.096170, Val loss: 1.098341, Val accuracy: 0.342831
# Epoch: 6/20, Step: 300, Loss: 1.092614, Val loss: 1.096827, Val accuracy: 0.342525
# Validation loss decreased (1.097245 --> 1.096827). Saving model...
# Epoch: 6/20, Step: 400, Loss: 1.085793, Val loss: 1.101362, Val accuracy: 0.340993
# Epoch: 6/20, Step: 500, Loss: 1.084373, Val loss: 1.094137, Val accuracy: 0.368719
# Validation loss decreased (1.096827 --> 1.094137). Saving model...
# Epoch: 6/20, Step: 600, Loss: 1.099575, Val loss: 1.098812, Val accuracy: 0.347580
# Epoch: 6/20, Step: 700, Loss: 1.092797, Val loss: 1.080438, Val accuracy: 0.404412
# Validation loss decreased (1.094137 --> 1.080438). Saving model...
# Epoch: 6/20, Step: 800, Loss: 1.042717, Val loss: 1.077625, Val accuracy: 0.410386
# Validation loss decreased (1.080438 --> 1.077625). Saving model...
# Epoch: 7/20, Step: 100, Loss: 1.074039, Val loss: 1.071194, Val accuracy: 0.390165
# Validation loss decreased (1.077625 --> 1.071194). Saving model...
# Epoch: 7/20, Step: 200, Loss: 1.077302, Val loss: 1.055232, Val accuracy: 0.451287
# Validation loss decreased (1.071194 --> 1.055232). Saving model...
# Epoch: 7/20, Step: 300, Loss: 1.092840, Val loss: 1.045864, Val accuracy: 0.456955
# Validation loss decreased (1.055232 --> 1.045864). Saving model...
# Epoch: 7/20, Step: 400, Loss: 1.088377, Val loss: 1.071314, Val accuracy: 0.422794
# Epoch: 7/20, Step: 500, Loss: 1.077585, Val loss: 1.065784, Val accuracy: 0.437653
# Epoch: 7/20, Step: 600, Loss: 1.021443, Val loss: 1.066132, Val accuracy: 0.428002
# Epoch: 7/20, Step: 700, Loss: 1.053026, Val loss: 1.060803, Val accuracy: 0.444087
# Epoch: 7/20, Step: 800, Loss: 1.072812, Val loss: 1.085775, Val accuracy: 0.387868
# Epoch: 8/20, Step: 100, Loss: 1.067866, Val loss: 1.055749, Val accuracy: 0.443781
# Epoch: 8/20, Step: 200, Loss: 1.031996, Val loss: 1.063944, Val accuracy: 0.457261
# Epoch: 8/20, Step: 300, Loss: 1.094926, Val loss: 1.097105, Val accuracy: 0.373928
# Epoch: 8/20, Step: 400, Loss: 1.041484, Val loss: 1.047418, Val accuracy: 0.460018
# Epoch: 8/20, Step: 500, Loss: 0.970972, Val loss: 1.053007, Val accuracy: 0.437806
# Epoch: 8/20, Step: 600, Loss: 1.106152, Val loss: 1.206437, Val accuracy: 0.330116
# Epoch: 8/20, Step: 700, Loss: 1.064246, Val loss: 1.043355, Val accuracy: 0.463695
# Validation loss decreased (1.045864 --> 1.043355). Saving model...
# Epoch: 8/20, Step: 800, Loss: 0.942736, Val loss: 1.032652, Val accuracy: 0.486366
# Validation loss decreased (1.043355 --> 1.032652). Saving model...
# Epoch: 9/20, Step: 100, Loss: 1.009666, Val loss: 1.029018, Val accuracy: 0.488971
# Validation loss decreased (1.032652 --> 1.029018). Saving model...
# Epoch: 9/20, Step: 200, Loss: 0.905335, Val loss: 1.014424, Val accuracy: 0.518076
# Validation loss decreased (1.029018 --> 1.014424). Saving model...
# Epoch: 9/20, Step: 300, Loss: 1.057571, Val loss: 1.020282, Val accuracy: 0.503523
# Epoch: 9/20, Step: 400, Loss: 1.017210, Val loss: 1.066792, Val accuracy: 0.467371
# Epoch: 9/20, Step: 500, Loss: 0.970853, Val loss: 1.020254, Val accuracy: 0.491881
# Epoch: 9/20, Step: 600, Loss: 1.169917, Val loss: 1.006317, Val accuracy: 0.516544
# Validation loss decreased (1.014424 --> 1.006317). Saving model...
# Epoch: 9/20, Step: 700, Loss: 1.064634, Val loss: 1.034829, Val accuracy: 0.489583
# Epoch: 9/20, Step: 800, Loss: 1.075664, Val loss: 1.017492, Val accuracy: 0.509804
# Epoch: 10/20, Step: 100, Loss: 0.974906, Val loss: 1.026903, Val accuracy: 0.497549
# Epoch: 10/20, Step: 200, Loss: 0.951314, Val loss: 1.025228, Val accuracy: 0.484375
# Epoch: 10/20, Step: 300, Loss: 0.983952, Val loss: 1.013029, Val accuracy: 0.509498
# Epoch: 10/20, Step: 400, Loss: 1.111868, Val loss: 1.004808, Val accuracy: 0.522672
# Validation loss decreased (1.006317 --> 1.004808). Saving model...
# Epoch: 10/20, Step: 500, Loss: 1.007089, Val loss: 1.008316, Val accuracy: 0.515012
# Epoch: 10/20, Step: 600, Loss: 0.975442, Val loss: 1.009745, Val accuracy: 0.518536
# Epoch: 10/20, Step: 700, Loss: 1.056086, Val loss: 1.021085, Val accuracy: 0.521293
# Epoch: 10/20, Step: 800, Loss: 1.011826, Val loss: 1.016156, Val accuracy: 0.514706
# Epoch: 11/20, Step: 100, Loss: 0.940622, Val loss: 1.001159, Val accuracy: 0.523744
# Validation loss decreased (1.004808 --> 1.001159). Saving model...
# Epoch: 11/20, Step: 200, Loss: 0.889905, Val loss: 0.998886, Val accuracy: 0.520987
# Validation loss decreased (1.001159 --> 0.998886). Saving model...
# Epoch: 11/20, Step: 300, Loss: 0.847210, Val loss: 1.012191, Val accuracy: 0.506434
# Epoch: 11/20, Step: 400, Loss: 1.065813, Val loss: 1.014227, Val accuracy: 0.487898
# Epoch: 11/20, Step: 500, Loss: 0.889965, Val loss: 1.043968, Val accuracy: 0.492034
# Epoch: 11/20, Step: 600, Loss: 0.817017, Val loss: 0.991539, Val accuracy: 0.540135
# Validation loss decreased (0.998886 --> 0.991539). Saving model...
# Epoch: 11/20, Step: 700, Loss: 0.971497, Val loss: 1.003480, Val accuracy: 0.519608
# Epoch: 11/20, Step: 800, Loss: 0.938963, Val loss: 0.984593, Val accuracy: 0.545190
# Validation loss decreased (0.991539 --> 0.984593). Saving model...
# Epoch: 12/20, Step: 100, Loss: 0.976560, Val loss: 1.019656, Val accuracy: 0.523744
# Epoch: 12/20, Step: 200, Loss: 0.836709, Val loss: 0.984201, Val accuracy: 0.552237
# Validation loss decreased (0.984593 --> 0.984201). Saving model...
# Epoch: 12/20, Step: 300, Loss: 0.765676, Val loss: 0.975332, Val accuracy: 0.552543
# Validation loss decreased (0.984201 --> 0.975332). Saving model...
# Epoch: 12/20, Step: 400, Loss: 0.932864, Val loss: 0.992853, Val accuracy: 0.545803
# Epoch: 12/20, Step: 500, Loss: 1.022490, Val loss: 0.999779, Val accuracy: 0.533088
# Epoch: 12/20, Step: 600, Loss: 0.841049, Val loss: 0.989911, Val accuracy: 0.552849
# Epoch: 12/20, Step: 700, Loss: 0.983546, Val loss: 1.004493, Val accuracy: 0.535080
# Epoch: 12/20, Step: 800, Loss: 1.019767, Val loss: 0.984273, Val accuracy: 0.558824
# Epoch: 13/20, Step: 100, Loss: 0.854672, Val loss: 0.990999, Val accuracy: 0.550398
# Epoch: 13/20, Step: 200, Loss: 0.820824, Val loss: 0.982196, Val accuracy: 0.562653
# Epoch: 13/20, Step: 300, Loss: 0.946556, Val loss: 0.987782, Val accuracy: 0.552543
# Epoch: 13/20, Step: 400, Loss: 1.052042, Val loss: 0.987487, Val accuracy: 0.555300
# Epoch: 13/20, Step: 500, Loss: 0.828477, Val loss: 0.982910, Val accuracy: 0.558824
# Epoch: 13/20, Step: 600, Loss: 0.838497, Val loss: 0.985859, Val accuracy: 0.550858
# Epoch: 13/20, Step: 700, Loss: 0.883028, Val loss: 0.985977, Val accuracy: 0.557138
# Epoch: 13/20, Step: 800, Loss: 1.038036, Val loss: 0.994627, Val accuracy: 0.539522
# Epoch: 14/20, Step: 100, Loss: 0.666388, Val loss: 0.988193, Val accuracy: 0.551930
# Epoch: 14/20, Step: 200, Loss: 0.994714, Val loss: 1.008478, Val accuracy: 0.531097
# Epoch: 14/20, Step: 300, Loss: 0.891282, Val loss: 1.033351, Val accuracy: 0.501379
# Epoch: 14/20, Step: 400, Loss: 1.014024, Val loss: 0.978718, Val accuracy: 0.557138
# Epoch: 14/20, Step: 500, Loss: 0.934697, Val loss: 1.004710, Val accuracy: 0.525429
# Epoch: 14/20, Step: 600, Loss: 1.011587, Val loss: 1.003031, Val accuracy: 0.539216
# Epoch: 14/20, Step: 700, Loss: 0.789992, Val loss: 0.984940, Val accuracy: 0.547947
# Epoch: 14/20, Step: 800, Loss: 0.843044, Val loss: 0.988575, Val accuracy: 0.547488
# Epoch: 15/20, Step: 100, Loss: 0.832531, Val loss: 1.008782, Val accuracy: 0.524203
# Epoch: 15/20, Step: 200, Loss: 0.849788, Val loss: 1.005071, Val accuracy: 0.533241
# Epoch: 15/20, Step: 300, Loss: 0.943871, Val loss: 0.983610, Val accuracy: 0.559896
# Epoch: 15/20, Step: 400, Loss: 0.805023, Val loss: 0.990560, Val accuracy: 0.555607
# Epoch: 15/20, Step: 500, Loss: 1.000986, Val loss: 1.007348, Val accuracy: 0.530637
# Epoch: 15/20, Step: 600, Loss: 0.897542, Val loss: 0.994699, Val accuracy: 0.540901
# Epoch: 15/20, Step: 700, Loss: 0.833077, Val loss: 0.989764, Val accuracy: 0.543811
# Epoch: 15/20, Step: 800, Loss: 0.793662, Val loss: 0.985040, Val accuracy: 0.553922
# Epoch: 16/20, Step: 100, Loss: 0.896810, Val loss: 0.986558, Val accuracy: 0.555607
# Epoch: 16/20, Step: 200, Loss: 0.758713, Val loss: 0.982545, Val accuracy: 0.555760
# Epoch: 16/20, Step: 300, Loss: 0.835730, Val loss: 0.974283, Val accuracy: 0.558517
# Validation loss decreased (0.975332 --> 0.974283). Saving model...
# Epoch: 16/20, Step: 400, Loss: 0.770306, Val loss: 0.985901, Val accuracy: 0.561121
# Epoch: 16/20, Step: 500, Loss: 0.838425, Val loss: 0.987915, Val accuracy: 0.558211
# Epoch: 16/20, Step: 600, Loss: 0.940228, Val loss: 0.981345, Val accuracy: 0.560509
# Epoch: 16/20, Step: 700, Loss: 0.913141, Val loss: 0.982715, Val accuracy: 0.559130
# Epoch: 16/20, Step: 800, Loss: 0.928490, Val loss: 0.982100, Val accuracy: 0.563725
# Epoch: 17/20, Step: 100, Loss: 0.777740, Val loss: 0.982647, Val accuracy: 0.560662
# Epoch: 17/20, Step: 200, Loss: 0.884308, Val loss: 0.990610, Val accuracy: 0.555300
# Epoch: 17/20, Step: 300, Loss: 0.812292, Val loss: 0.993249, Val accuracy: 0.550398
# Epoch: 17/20, Step: 400, Loss: 0.775140, Val loss: 0.980315, Val accuracy: 0.560509
# Epoch: 17/20, Step: 500, Loss: 0.775074, Val loss: 0.988809, Val accuracy: 0.556679
# Epoch: 17/20, Step: 600, Loss: 1.026697, Val loss: 0.985347, Val accuracy: 0.562347
# Epoch: 17/20, Step: 700, Loss: 0.871912, Val loss: 0.980057, Val accuracy: 0.568781
# Epoch: 17/20, Step: 800, Loss: 0.867612, Val loss: 0.990456, Val accuracy: 0.553462
# Epoch: 18/20, Step: 100, Loss: 0.906633, Val loss: 0.984527, Val accuracy: 0.559436
# Epoch: 18/20, Step: 200, Loss: 0.926238, Val loss: 0.997124, Val accuracy: 0.549479
# Epoch: 18/20, Step: 300, Loss: 0.770138, Val loss: 0.995984, Val accuracy: 0.554381
# Epoch: 18/20, Step: 400, Loss: 0.926530, Val loss: 1.003957, Val accuracy: 0.545343
# Epoch: 18/20, Step: 500, Loss: 0.861600, Val loss: 0.984928, Val accuracy: 0.561121
# Epoch: 18/20, Step: 600, Loss: 1.051439, Val loss: 1.031804, Val accuracy: 0.518229
# Epoch: 18/20, Step: 700, Loss: 0.738978, Val loss: 0.987601, Val accuracy: 0.561275
# Epoch: 18/20, Step: 800, Loss: 0.864012, Val loss: 0.993365, Val accuracy: 0.557138
# Epoch: 19/20, Step: 100, Loss: 0.833913, Val loss: 0.988262, Val accuracy: 0.559436
# Epoch: 19/20, Step: 200, Loss: 0.817969, Val loss: 0.997708, Val accuracy: 0.547794
# Epoch: 19/20, Step: 300, Loss: 0.810372, Val loss: 0.984578, Val accuracy: 0.561887
# Epoch: 19/20, Step: 400, Loss: 0.954913, Val loss: 0.995314, Val accuracy: 0.551777
# Epoch: 19/20, Step: 500, Loss: 0.881001, Val loss: 0.980038, Val accuracy: 0.564185
# Epoch: 19/20, Step: 600, Loss: 0.842244, Val loss: 0.979895, Val accuracy: 0.566789
# Epoch: 19/20, Step: 700, Loss: 0.853197, Val loss: 0.981787, Val accuracy: 0.562960
# Epoch: 19/20, Step: 800, Loss: 0.945916, Val loss: 0.986759, Val accuracy: 0.560509
# Epoch: 20/20, Step: 100, Loss: 0.659283, Val loss: 0.988844, Val accuracy: 0.557292
# Epoch: 20/20, Step: 200, Loss: 0.952166, Val loss: 0.987404, Val accuracy: 0.559743
# Epoch: 20/20, Step: 300, Loss: 0.890567, Val loss: 0.989189, Val accuracy: 0.558364
# Epoch: 20/20, Step: 400, Loss: 0.964027, Val loss: 0.980029, Val accuracy: 0.567708
# Epoch: 20/20, Step: 500, Loss: 0.843951, Val loss: 0.988057, Val accuracy: 0.557751
# Epoch: 20/20, Step: 600, Loss: 0.677777, Val loss: 0.989877, Val accuracy: 0.555147
# Epoch: 20/20, Step: 700, Loss: 0.843159, Val loss: 0.984173, Val accuracy: 0.557904
# Epoch: 20/20, Step: 800, Loss: 0.847450, Val loss: 0.980438, Val accuracy: 0.566330

# %%
epochs = range(1, len(train_losses) + 1)

plt.plot(epochs, train_losses, 'b', label='Training loss')
plt.plot(epochs, valid_losses, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
net.load_state_dict(torch.load(model_name))
net.to(device)
# Out:
# SentimentRNN(
#   (embedding): Embedding(55991, 128)
#   (lstm): LSTM(128, 256, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=256, out_features=3, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
test_losses = []
num_correct = 0

h = net.init_hidden(batch_size)

net.eval()

for inputs, labels in test_loader:
    h = tuple([each.data for each in h])
    inputs, labels = inputs.to(device), labels.to(device)
    
    output, h = net(inputs, h)
    test_loss = criterion(output, labels)
    test_losses.append(test_loss.item())
    
    pred = torch.argmax(output, dim=1)
    correct_tensor = pred.eq(labels)
    num_correct += torch.sum(correct_tensor).item()

print("Test loss: {:.6f}".format(np.mean(test_losses)))

test_acc = num_correct/len(test_loader.dataset)
print("Test accuracy: {:.6f}".format(test_acc))
# Out:
# Test loss: 1.016224
# Test accuracy: 0.506154

# %%
def predict(model, sentence):
    words = clean_text(sentence)
    text_ints = phrase_to_ints(words)
    padded_text = pad_sequences(text_ints, seq_length)
    
    text_tensor = torch.from_numpy(padded_text)
    text_tensor = text_tensor.to(device)
    
    model.eval()
    
    batch_size = text_tensor.size(0)
    h = model.init_hidden(batch_size)
    
    output, _ = model(text_tensor, h)
    predicted = output.flatten().cpu().detach().numpy()
    label = np.argmax(predicted)
    
    return predicted, label

# %%
sentence = "Lovely yet not that good.Could've been better."
predicted, label = predict(net, sentence)
labels = ['Negative', 'Neutral', 'Positive']
print(predicted)
print(labels[label])
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [0.6736936  0.32305947 0.00324687]
# Negative
